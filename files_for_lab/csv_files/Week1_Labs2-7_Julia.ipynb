# %% [markdown]
# # ROUND 2

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('marketing_customer_analysis.csv')
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %% [markdown]
# # Standardize DataFrame

# %%
dataset = dataset.drop(['Unnamed: 0'], axis=1)
col1 = list(map(lambda el : el.lower(),dataset))
dataset.columns = col1
dataset
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# # Checking data types

# %%
dataset.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
dataset.select_dtypes(include=np.object)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_9480\1320451494.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataset.select_dtypes(include=np.object)
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# ...

# %%
dataset.select_dtypes(include=np.number)
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %% [markdown]
# # Checking and dealing with NaN values

# %%
dataset.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# ...

# %%
dataset.describe(include=[np.object]).T
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_9480\1257540456.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataset.describe(include=[np.object]).T
#                    count unique            top  freq
# customer           10910   9134        ID89933     7
# state              10279      5     California  3552
# response           10279      2             No  8813
# coverage           10910      3          Basic  6660
# education          10910      5       Bachelor  3272
# effective to date  10910     59        1/10/11   239
# employmentstatus   10910      5       Employed  6789
# gender             10910      2              F  5573
# location code      10910      3       Suburban  6902
# ...

# %%
dataset.describe(include=[np.number]).T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10277.0     15.149071     10.080349
# months since policy inception  10910.0     48.091934     27.940675
# number of open complaints      10277.0      0.384256      0.912457
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     6.000000     14.000000
# ...

# %%
dataset[(dataset['state'].isna())&(dataset['response'].isna())|(dataset['months since last claim'].isna())&(dataset['number of open complaints'].isna())|(dataset['vehicle class'].isna())&(dataset['vehicle size'].isna())]
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 4      QA50777      Oregon              9025.067525       No   Premium
# 5      HO81102         NaN              4745.181764      NaN     Basic
# 11     GE63585         NaN              2420.711888      NaN     Basic
# 23     NQ71171  California              5107.071054       No     Basic
# 51     FT56968     Arizona              2590.096027       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10883  FD64348      Oregon             22563.618380       No     Basic
# 10890  VQ78876      Oregon              4660.399573       No     Basic
# 10894  EX63393         NaN              6314.492009      NaN  Extended
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
dataset[(dataset['state'].isna())&(dataset['response'].isna())&(dataset['months since last claim'].isna())&(dataset['number of open complaints'].isna())&(dataset['vehicle class'].isna())&(dataset['vehicle size'].isna())]
# Out:
#      customer state  customer lifetime value response  coverage education  \
# 2136  CY49953   NaN              2827.559570      NaN  Extended   College
# 3389  ID89933   NaN              7255.577594      NaN  Extended    Doctor
# 6743  ID89933   NaN              7255.577594      NaN  Extended    Doctor
# 8883  KE35335   NaN              3580.261881      NaN  Extended   College
# 9499  YV40022   NaN              9807.829589      NaN  Extended   College
#
#      effective to date employmentstatus gender  income  ...  \
# 2136           2/18/11       Unemployed      F       0  ...
# 3389            1/9/11         Employed      F   39786  ...
# 6743            1/9/11         Employed      F   39786  ...
# 8883           1/17/11         Employed      F   75333  ...
# 9499           1/18/11       Unemployed      F       0  ...
#
#      number of open complaints number of policies    policy type       policy  \
# ...

# %%
dataset[(dataset['vehicle class'].isna())&(dataset['vehicle size'].isna())&(dataset['vehicle type'].isna())]
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 87     ZH92587      Oregon              8126.766397       No     Basic
# 88     CJ51511     Arizona             13466.920710      Yes     Basic
# 163    TP34946  California              5108.038755       No     Basic
# 294    AM57175      Oregon             15000.842380       No  Extended
# 397    XV69290  California             22332.439460      Yes  Extended
# ...        ...         ...                      ...      ...       ...
# 10761  QO54008      Oregon             13419.396230       No  Extended
# 10770  TN50051  California              2957.764017       No     Basic
# 10860  GA79817     Arizona              2369.111588       No     Basic
# 10879  FK95213  California             18611.453560       No  Extended
# 10890  VQ78876      Oregon              4660.399573       No     Basic
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
dataset[['vehicle class','vehicle size','vehicle type']].head(10)
# Out:
#    vehicle class vehicle size vehicle type
# 0  Four-Door Car      Medsize        Not A
# 1  Four-Door Car      Medsize        Not A
# 2            SUV      Medsize            A
# 3  Four-Door Car      Medsize            A
# 4  Four-Door Car      Medsize        Not A
# 5  Four-Door Car      Medsize            A
# 6  Four-Door Car      Medsize        Not A
# 7   Two-Door Car      Medsize        Not A
# 8     Sports Car      Medsize        Not A
# 9  Four-Door Car        Small        Not A

# %% [markdown]
# # Filling NaN

# %%
#last column just have 1 value 'A', so NaN could be replaced with 'Not A'
dataset['vehicle type'] = dataset['vehicle type'].fillna('Not A')

# %%
#state column mode is California so I'm going to try replacing NaN with the mode in a new df just in case
new_dataset = dataset.copy()
new_dataset['state'] = new_dataset['state'].fillna('California')
new_dataset['state'].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', 'Nevada'],
#       dtype=object)

# %%
#response column I'm going to fill NaN with 'Not Sure' 
new_dataset['response'] = new_dataset['response'].fillna('Not Sure')
new_dataset['response'].unique()
# Out:
# array(['No', 'Yes', 'Not Sure'], dtype=object)

# %%
#vehicle class has 6 diferent options, so I'm going to fill NaN with 'Other'
new_dataset['vehicle class'] = new_dataset['vehicle class'].fillna('Other')
new_dataset['vehicle class'].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Sports Car', 'Luxury Car',
#        'Luxury SUV', 'Other'], dtype=object)

# %%
#vehicle size has 3 options: Smal, Large, Medsize (which is the mode) I'm going to replace NaN with the mode
new_dataset['vehicle size'] = new_dataset['vehicle size'].fillna('Medsize')
new_dataset['vehicle size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
new_dataset.describe(include=[np.number]).T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10277.0     15.149071     10.080349
# months since policy inception  10910.0     48.091934     27.940675
# number of open complaints      10277.0      0.384256      0.912457
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     6.000000     14.000000
# ...

# %%
#number of open complaints has a median of 0 and it's also the mode, so I'm going to fill the NaN with 0
new_dataset['number of open complaints'] = new_dataset['number of open complaints'].fillna(0)
new_dataset.describe(include=[np.number]).T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10277.0     15.149071     10.080349
# months since policy inception  10910.0     48.091934     27.940675
# number of open complaints      10910.0      0.361962      0.890134
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     6.000000     14.000000
# ...

# %% [markdown]
# It doesn't seem to afect very much to the mean and std so I think it's fine

# %%
#months since last claim replace with the median 14
new_dataset['months since last claim'] = new_dataset['months since last claim'].fillna(14)
new_dataset.describe(include=[np.number]).T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10910.0     15.082401      9.787208
# months since policy inception  10910.0     48.091934     27.940675
# number of open complaints      10910.0      0.361962      0.890134
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     7.000000     14.000000
# ...

# %% [markdown]
# I tried to replace it with the mean first, but I think the median distorts less all the data

# %%
new_dataset.isna().sum()
# Out:
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# vehicle type                     0
# dtype: int64

# %% [markdown]
# # Extract the months from the dataset

# %%
new_dataset
# Out:
#       customer       state  customer lifetime value  response  coverage  \
# 0      DK49336     Arizona              4809.216960        No     Basic
# 1      KX64629  California              2228.525238        No     Basic
# 2      LZ68649  Washington             14947.917300        No     Basic
# 3      XL78013      Oregon             22332.439460       Yes  Extended
# 4      QA50777      Oregon              9025.067525        No   Premium
# ...        ...         ...                      ...       ...       ...
# 10905  FE99816      Nevada             15563.369440        No   Premium
# 10906  KX53892      Oregon              5259.444853        No     Basic
# 10907  TL39050     Arizona             23893.304100        No  Extended
# 10908  WA60547  California             11971.977650        No   Premium
# 10909  IV32877  California              6857.519928  Not Sure     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
new_dataset['effective to date'] = pd.to_datetime(new_dataset['effective to date'], errors='coerce')
new_dataset.dtypes
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints               float64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %%
# #new columns
# data['percent_income_donated'] = data['target_d']/data['median_household_income']
# data.head()
new_dataset ['month'] = new_dataset ['effective to date'][0].month
new_dataset
# Out:
#       customer       state  customer lifetime value  response  coverage  \
# 0      DK49336     Arizona              4809.216960        No     Basic
# 1      KX64629  California              2228.525238        No     Basic
# 2      LZ68649  Washington             14947.917300        No     Basic
# 3      XL78013      Oregon             22332.439460       Yes  Extended
# 4      QA50777      Oregon              9025.067525        No   Premium
# ...        ...         ...                      ...       ...       ...
# 10905  FE99816      Nevada             15563.369440        No   Premium
# 10906  KX53892      Oregon              5259.444853        No     Basic
# 10907  TL39050     Arizona             23893.304100        No  Extended
# 10908  WA60547  California             11971.977650        No   Premium
# 10909  IV32877  California              6857.519928  Not Sure     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
#extracting the month in a new column
month = []
i=0
for date in new_dataset['effective to date']:
    new_month = new_dataset['effective to date'][i].month
    month.append(new_month)
    i+=1

# %%
new_dataset['month'] = month
new_dataset
# Out:
#       customer       state  customer lifetime value  response  coverage  \
# 0      DK49336     Arizona              4809.216960        No     Basic
# 1      KX64629  California              2228.525238        No     Basic
# 2      LZ68649  Washington             14947.917300        No     Basic
# 3      XL78013      Oregon             22332.439460       Yes  Extended
# 4      QA50777      Oregon              9025.067525        No   Premium
# ...        ...         ...                      ...       ...       ...
# 10905  FE99816      Nevada             15563.369440        No   Premium
# 10906  KX53892      Oregon              5259.444853        No     Basic
# 10907  TL39050     Arizona             23893.304100        No  Extended
# 10908  WA60547  California             11971.977650        No   Premium
# 10909  IV32877  California              6857.519928  Not Sure     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# # Filtering January and February

# %%
filtered_data = new_dataset[(new_dataset['month']==1)|(new_dataset['month']==2)]
filtered_data
# Out:
#       customer       state  customer lifetime value  response  coverage  \
# 0      DK49336     Arizona              4809.216960        No     Basic
# 1      KX64629  California              2228.525238        No     Basic
# 2      LZ68649  Washington             14947.917300        No     Basic
# 3      XL78013      Oregon             22332.439460       Yes  Extended
# 4      QA50777      Oregon              9025.067525        No   Premium
# ...        ...         ...                      ...       ...       ...
# 10905  FE99816      Nevada             15563.369440        No   Premium
# 10906  KX53892      Oregon              5259.444853        No     Basic
# 10907  TL39050     Arizona             23893.304100        No  Extended
# 10908  WA60547  California             11971.977650        No   Premium
# 10909  IV32877  California              6857.519928  Not Sure     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# # Making a function for all of the above (I'll try later)

# %% [markdown]
# # Droping vehicle type (maybe check this later)

# %%
dataset2 = new_dataset.drop(['vehicle type'],axis=1)
dataset2
# Out:
#       customer       state  customer lifetime value  response  coverage  \
# 0      DK49336     Arizona              4809.216960        No     Basic
# 1      KX64629  California              2228.525238        No     Basic
# 2      LZ68649  Washington             14947.917300        No     Basic
# 3      XL78013      Oregon             22332.439460       Yes  Extended
# 4      QA50777      Oregon              9025.067525        No   Premium
# ...        ...         ...                      ...       ...       ...
# 10905  FE99816      Nevada             15563.369440        No   Premium
# 10906  KX53892      Oregon              5259.444853        No     Basic
# 10907  TL39050     Arizona             23893.304100        No  Extended
# 10908  WA60547  California             11971.977650        No   Premium
# 10909  IV32877  California              6857.519928  Not Sure     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# # Round 3
